# %%
# %pip install crewai crewai-tools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: crewai in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (1.11.0)
# Requirement already satisfied: crewai-tools in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (1.11.0)
# Requirement already satisfied: aiosqlite~=0.21.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (0.21.0)
# Requirement already satisfied: appdirs~=1.4.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: chromadb~=1.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.1.1)
# Requirement already satisfied: click~=8.1.7 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (8.1.8)
# Requirement already satisfied: httpx~=0.28.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (0.28.1)
# Requirement already satisfied: instructor>=1.3.3 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.14.5)
# Requirement already satisfied: json-repair~=0.25.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (0.25.3)
# Requirement already satisfied: json5~=0.10.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (0.10.0)
# Requirement already satisfied: jsonref~=1.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: lancedb>=0.29.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (0.30.0)
# Requirement already satisfied: mcp~=1.26.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.26.0)
# Requirement already satisfied: openai<3,>=1.83.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (2.21.0)
# Requirement already satisfied: openpyxl~=3.1.5 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api~=1.34.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http~=1.34.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk~=1.34.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: pdfplumber~=0.11.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (0.11.9)
# Requirement already satisfied: portalocker~=2.7.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings~=2.10.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (2.10.1)
# Requirement already satisfied: pydantic~=2.11.9 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (2.11.10)
# Requirement already satisfied: pyjwt<3,>=2.9.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (2.12.1)
# Requirement already satisfied: python-dotenv~=1.1.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.1.1)
# Requirement already satisfied: regex~=2026.1.15 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (2026.1.15)
# Requirement already satisfied: textual>=7.5.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (8.1.1)
# Requirement already satisfied: tokenizers<1,>=0.21 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (0.22.2)
# Requirement already satisfied: tomli-w~=1.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli~=2.0.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (2.0.2)
# Requirement already satisfied: uv~=0.9.13 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai) (0.9.30)
# Requirement already satisfied: typing_extensions>=4.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiosqlite~=0.21.0->crewai) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.41.0)
# Requirement already satisfied: numpy>=1.22.5 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (2.4.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (1.24.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (1.78.1)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (0.23.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (3.11.7)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from chromadb~=1.1.0->crewai) (4.26.0)
# Requirement already satisfied: colorama in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from click~=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: anyio in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx~=0.28.1->crewai) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx~=0.28.1->crewai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx~=0.28.1->crewai) (1.0.9)
# Requirement already satisfied: idna in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx~=0.28.1->crewai) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpcore==1.*->httpx~=0.28.1->crewai) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from mcp~=1.26.0->crewai) (0.4.3)
# Requirement already satisfied: python-multipart>=0.0.9 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from mcp~=1.26.0->crewai) (0.0.22)
# Requirement already satisfied: pywin32>=310 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from mcp~=1.26.0->crewai) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from mcp~=1.26.0->crewai) (3.3.3)
# Requirement already satisfied: starlette>=0.27 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from mcp~=1.26.0->crewai) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from mcp~=1.26.0->crewai) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from openai<3,>=1.83.0->crewai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from openai<3,>=1.83.0->crewai) (0.11.1)
# Requirement already satisfied: sniffio in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from openai<3,>=1.83.0->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from openpyxl~=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-api~=1.34.0->crewai) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.34.0->crewai) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.34.1)
# Requirement already satisfied: requests~=2.7 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (2.32.5)
# Requirement already satisfied: protobuf<6.0,>=5.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-proto==1.34.1->opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (5.29.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from opentelemetry-sdk~=1.34.0->crewai) (0.55b1)
# Requirement already satisfied: pdfminer.six==20251230 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pdfplumber~=0.11.4->crewai) (20251230)
# Requirement already satisfied: Pillow>=9.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pdfplumber~=0.11.4->crewai) (12.1.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pdfplumber~=0.11.4->crewai) (5.6.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pdfminer.six==20251230->pdfplumber~=0.11.4->crewai) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pdfminer.six==20251230->pdfplumber~=0.11.4->crewai) (46.0.5)
# Requirement already satisfied: six>=1.5 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic~=2.11.9->crewai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic~=2.11.9->crewai) (2.33.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (2.6.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from tokenizers<1,>=0.21->crewai) (1.4.1)
# Requirement already satisfied: filelock in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (26.0)
# Requirement already satisfied: shellingham in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (1.5.4)
# Requirement already satisfied: typer-slim in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (0.23.1)
# Requirement already satisfied: beautifulsoup4~=4.13.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai-tools) (4.13.5)
# Requirement already satisfied: docker~=7.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai-tools) (7.1.0)
# Requirement already satisfied: pymupdf~=1.26.6 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai-tools) (1.26.7)
# Requirement already satisfied: python-docx~=1.2.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai-tools) (1.2.0)
# Requirement already satisfied: pytube~=15.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai-tools) (15.0.0)
# Requirement already satisfied: tiktoken~=0.8.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai-tools) (0.8.0)
# Requirement already satisfied: youtube-transcript-api~=1.2.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from crewai-tools) (1.2.4)
# Requirement already satisfied: soupsieve>1.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from beautifulsoup4~=4.13.4->crewai-tools) (2.8.3)
# Requirement already satisfied: lxml>=3.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-docx~=1.2.0->crewai-tools) (6.0.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from youtube-transcript-api~=1.2.2->crewai-tools) (0.7.1)
# Requirement already satisfied: pyproject_hooks in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber~=0.11.4->crewai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber~=0.11.4->crewai) (3.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from instructor>=1.3.3->crewai) (3.13.3)
# Requirement already satisfied: diskcache>=5.6.3 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from instructor>=1.3.3->crewai) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from instructor>=1.3.3->crewai) (3.1.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (2.19.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (0.0.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: deprecation>=2.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from lancedb>=0.29.2->crewai) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from lancedb>=0.29.2->crewai) (23.0.1)
# Requirement already satisfied: lance-namespace>=0.3.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from lancedb>=0.29.2->crewai) (0.6.1)
# Requirement already satisfied: lance-namespace-urllib3-client==0.6.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from lance-namespace>=0.3.2->lancedb>=0.29.2->crewai) (0.6.1)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai) (0.1.2)
# Requirement already satisfied: flatbuffers in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.12.19)
# Requirement already satisfied: sympy in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.14.0)
# Requirement already satisfied: mdit-py-plugins in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from textual>=7.5.0->crewai) (0.5.0)
# Requirement already satisfied: platformdirs<5,>=3.6.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from textual>=7.5.0->crewai) (4.9.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai) (2.1.0)
# Requirement already satisfied: uc-micro-py in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai) (2.0.0)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain_community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain_community in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (1.2.14)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (2.0.46)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (0.7.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain_community) (2.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.11.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.3)
# Requirement already satisfied: greenlet>=1 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %pip install pywin32
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pywin32 in C:\Users\krant\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (311)
# Note: you may need to restart the kernel to use updated packages.

# %%
from crewai import Agent, Task, Crew

# %%
import os

os.environ["OPENAI_API_KEY"] = ""
os.environ["OPENAI_MODEL_NAME"] = "gpt-3.5-turbo"

# %%
planner = Agent(
    role="Content Planner",
    goal="Plan engaging and factually accurate content on {topic}",
    backstory="You're working on planning a blog article "
              "about the topic: {topic}."
              "You collect information that helps the "
              "audience learn something "
              "and make informed decisions. "
              "Your work is the basis for "
              "the Content Writer to write an article on this topic.",
    allow_delegation=False,
	verbose=True
)

# %%
writer = Agent(
    role="Content Writer",
    goal="Write insightful and factually accurate "
         "opinion piece about the topic: {topic}",
    backstory="You're working on a writing "
              "a new opinion piece about the topic: {topic}. "
              "You base your writing on the work of "
              "the Content Planner, who provides an outline "
              "and relevant context about the topic. "
              "You follow the main objectives and "
              "direction of the outline, "
              "as provide by the Content Planner. "
              "You also provide objective and impartial insights "
              "and back them up with information "
              "provide by the Content Planner. "
              "You acknowledge in your opinion piece "
              "when your statements are opinions "
              "as opposed to objective statements.",
    allow_delegation=False,
    verbose=True
)

# %%
editor = Agent(
    role="Editor",
    goal="Edit a given blog post to align with "
         "the writing style of the organization. ",
    backstory="You are an editor who receives a blog post "
              "from the Content Writer. "
              "Your goal is to review the blog post "
              "to ensure that it follows journalistic best practices,"
              "provides balanced viewpoints "
              "when providing opinions or assertions, "
              "and also avoids major controversial topics "
              "or opinions when possible.",
    allow_delegation=False,
    verbose=True
)

# %%
plan = Task(
    description=(
        "1. Prioritize the latest trends, key players, "
            "and noteworthy news on {topic}.\n"
        "2. Identify the target audience, considering "
            "their interests and pain points.\n"
        "3. Develop a detailed content outline including "
            "an introduction, key points, and a call to action.\n"
        "4. Include SEO keywords and relevant data or sources."
    ),
    expected_output="A comprehensive content plan document "
        "with an outline, audience analysis, "
        "SEO keywords, and resources.",
    agent=planner,
)

# %%
write = Task(
    description=(
        "1. Use the content plan to craft a compelling "
            "blog post on {topic}.\n"
        "2. Incorporate SEO keywords naturally.\n"
		"3. Sections/Subtitles are properly named "
            "in an engaging manner.\n"
        "4. Ensure the post is structured with an "
            "engaging introduction, insightful body, "
            "and a summarizing conclusion.\n"
        "5. Proofread for grammatical errors and "
            "alignment with the brand's voice.\n"
    ),
    expected_output="A well-written blog post "
        "in markdown format, ready for publication, "
        "each section should have 2 or 3 paragraphs.",
    agent=writer,
)

# %%
edit = Task(
    description=("Proofread the given blog post for "
                 "grammatical errors and "
                 "alignment with the brand's voice."),
    expected_output="A well-written blog post in markdown format, "
                    "ready for publication, "
                    "each section should have 2 or 3 paragraphs.",
    agent=editor
)

# %%
crew = Crew(
    agents=[planner, writer, editor],
    tasks=[plan, write, edit],
    verbose=True
)

# %%
result = crew.kickoff(inputs={"topic": "Artificial Intelligence"})
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 9b5b42e2-43ae-43e4-865d-8bfec685e4fc                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Prioritize the latest trends, key players, and noteworthy news on Artificial Intelligence.            │
# │  2. Identify the target audience, considering their interests and pain points.                                  │
# │  3. Develop a detailed content outline including an introduction, key points, and a call to action.             │
# │  4. Include SEO keywords and relevant data or sources.                                                          │
# │  ID: 60c2a804-4804-4158-bc06-359abb9081a1                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │  Task: 1. Prioritize the latest trends, key players, and noteworthy news on Artificial Intelligence.            │
# │  2. Identify the target audience, considering their interests and pain points.                                  │
# │  3. Develop a detailed content outline including an introduction, key points, and a call to action.             │
# │  4. Include SEO keywords and relevant data or sources.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Content Plan: Artificial Intelligence in 2021                                                                  │
# │                                                                                                                 │
# │  Outline:                                                                                                       │
# │  I. Introduction                                                                                                │
# │      A. Definition of Artificial Intelligence                                                                   │
# │      B. Importance of Artificial Intelligence in today's world                                                  │
# │  II. Latest Trends in Artificial Intelligence                                                                   │
# │      A. Machine Learning and Deep Learning advancements                                                         │
# │      B. Natural Language Processing (NLP) innovations                                                           │
# │      C. AI ethics and responsible AI practices                                                                  │
# │  III. Key Players in the Artificial Intelligence Industry                                                       │
# │      A. Google Brain                                                                                            │
# │      B. OpenAI                                                                                                  │
# │      C. IBM Watson                                                                                              │
# │      D. Microsoft Azure AI                                                                                      │
# │  IV. Noteworthy News in the Artificial Intelligence Field                                                       │
# │      A. Breakthrough in autonomous vehicles technology                                                          │
# │      B. AI-powered healthcare diagnostics                                                                       │
# │      C. Rise of AI in business automation                                                                       │
# │  V. Target Audience Analysis                                                                                    │
# │      A. Professionals in tech industries interested in AI advancements                                          │
# │      B. Business owners looking to implement AI solutions                                                       │
# │      C. Students and researchers studying Artificial Intelligence                                               │
# │  VI. SEO Keywords                                                                                               │
# │      A. Artificial Intelligence trends                                                                          │
# │      B. AI innovations 2021                                                                                     │
# │      C. Top AI companies                                                                                        │
# │  VII. Resources                                                                                                 │
# │      A. "The AI Organization" - artificial intelligence news and insights                                       │
# │      B. Forbes Technology section for AI-related articles                                                       │
# │      C. Research papers from top AI conferences like NeurIPS and ICML                                           │
# │  VIII. Call to Action                                                                                           │
# │      A. Encourage readers to stay updated on the latest AI trends and developments                              │
# │      B. Offer a free AI trends report download in exchange for email subscription                               │
# │                                                                                                                 │
# │  Audience Analysis:                                                                                             │
# │  The target audience for this blog article includes professionals in tech industries who are interested in      │
# │  staying updated on the latest advancements in Artificial Intelligence. Business owners looking to implement    │
# │  AI solutions in their companies will also benefit from the insights provided. Additionally, students and       │
# │  researchers studying Artificial Intelligence will find value in understanding the key trends and players       │
# │  shaping the industry in 2021.                                                                                  │
# │                                                                                                                 │
# │  Please use the outlined information to develop a detailed blog article on Artificial Intelligence.             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1. Prioritize the latest trends, key players, and noteworthy news on Artificial Intelligence.            │
# │  2. Identify the target audience, considering their interests and pain points.                                  │
# │  3. Develop a detailed content outline including an introduction, key points, and a call to action.             │
# │  4. Include SEO keywords and relevant data or sources.                                                          │
# │  Agent: Content Planner                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: 1. Use the content plan to craft a compelling blog post on Artificial Intelligence.                      │
# │  2. Incorporate SEO keywords naturally.                                                                         │
# │  3. Sections/Subtitles are properly named in an engaging manner.                                                │
# │  4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing             │
# │  conclusion.                                                                                                    │
# │  5. Proofread for grammatical errors and alignment with the brand's voice.                                      │
# │                                                                                                                 │
# │  ID: bd6cd446-6fb8-4700-9026-2599f79536fd                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │  Task: 1. Use the content plan to craft a compelling blog post on Artificial Intelligence.                      │
# │  2. Incorporate SEO keywords naturally.                                                                         │
# │  3. Sections/Subtitles are properly named in an engaging manner.                                                │
# │  4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing             │
# │  conclusion.                                                                                                    │
# │  5. Proofread for grammatical errors and alignment with the brand's voice.                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Embracing Artificial Intelligence in 2021: A Sneak Peek into the Future                                      │
# │                                                                                                                 │
# │  Artificial Intelligence (AI), a term that once belonged to the realm of science fiction, has now become an     │
# │  integral part of our everyday lives. In simple terms, AI refers to the simulation of human intelligence        │
# │  processes by machines, primarily computer systems. The significance of AI in today's world cannot be           │
# │  overstated, as it permeates various sectors, driving innovation, efficiency, and new possibilities.            │
# │                                                                                                                 │
# │  ## Latest Trends in Artificial Intelligence                                                                    │
# │                                                                                                                 │
# │  ### Machine Learning and Deep Learning Advancements                                                            │
# │  One of the most remarkable trends in AI is the continuous evolution of Machine Learning and Deep Learning      │
# │  algorithms. These technologies enable machines to learn from data, recognize patterns, and make decisions      │
# │  with minimal human intervention. From image recognition to speech synthesis, the applications of these         │
# │  advancements are limitless.                                                                                    │
# │                                                                                                                 │
# │  ### Natural Language Processing (NLP) Innovations                                                              │
# │  Natural Language Processing, a subset of AI, focuses on enabling computers to understand, interpret, and       │
# │  generate human language. In 2021, NLP has seen significant breakthroughs, leading to advancements in virtual   │
# │  assistants, sentiment analysis, and language translation services, transforming the way we interact with       │
# │  technology.                                                                                                    │
# │                                                                                                                 │
# │  ### AI Ethics and Responsible AI Practices                                                                     │
# │  With the proliferation of AI technologies, the importance of ethical considerations and responsible AI         │
# │  practices has come to the forefront. Ensuring fairness, transparency, and accountability in AI systems is      │
# │  crucial to building trust and mitigating potential risks associated with their deployment.                     │
# │                                                                                                                 │
# │  ## Key Players in the Artificial Intelligence Industry                                                         │
# │                                                                                                                 │
# │  The landscape of the AI industry is populated by key players that drive innovation and shape the future of     │
# │  technology.                                                                                                    │
# │                                                                                                                 │
# │  ### Google Brain                                                                                               │
# │  Google Brain, an AI research team at Google, is at the forefront of developing cutting-edge machine learning   │
# │  algorithms and advancing AI research. Their contributions have significantly influenced the evolution of AI    │
# │  technologies globally.                                                                                         │
# │                                                                                                                 │
# │  ### OpenAI                                                                                                     │
# │  OpenAI is a research organization dedicated to ensuring that artificial general intelligence (AGI) benefits    │
# │  all of humanity. With a focus on transparency and collaboration, OpenAI is pushing the boundaries of what AI   │
# │  can achieve.                                                                                                   │
# │                                                                                                                 │
# │  ### IBM Watson                                                                                                 │
# │  IBM Watson, an AI-powered cognitive computing platform, is renowned for its capabilities in data analysis,     │
# │  natural language processing, and machine learning. Businesses across various industries leverage IBM Watson    │
# │  to gain insights, automate processes, and drive innovation.                                                    │
# │                                                                                                                 │
# │  ### Microsoft Azure AI                                                                                         │
# │  Microsoft Azure AI offers a range of AI services and tools to help organizations build AI solutions, from      │
# │  chatbots to predictive analytics. With a commitment to democratizing AI, Microsoft is empowering businesses    │
# │  to harness the power of artificial intelligence.                                                               │
# │                                                                                                                 │
# │  ## Noteworthy News in the Artificial Intelligence Field                                                        │
# │                                                                                                                 │
# │  ### Breakthrough in Autonomous Vehicles Technology                                                             │
# │  Advancements in AI have paved the way for significant breakthroughs in autonomous vehicles technology. From    │
# │  self-driving cars to intelligent transportation systems, AI is revolutionizing the way we think about          │
# │  transportation and mobility.                                                                                   │
# │                                                                                                                 │
# │  ### AI-Powered Healthcare Diagnostics                                                                          │
# │  In the healthcare sector, AI is transforming diagnostics and personalized medicine. AI-powered algorithms can  │
# │  analyze medical images, genetic data, and patient records to assist healthcare professionals in making         │
# │  accurate diagnoses and treatment decisions.                                                                    │
# │                                                                                                                 │
# │  ### Rise of AI in Business Automation                                                                          │
# │  AI is playing a pivotal role in streamlining business operations through automation. From optimizing supply    │
# │  chains to enhancing customer service through chatbots, AI is reshaping the way businesses operate and          │
# │  interact with customers.                                                                                       │
# │                                                                                                                 │
# │  ## Call to Action                                                                                              │
# │                                                                                                                 │
# │  As we venture further into the era of Artificial Intelligence, I encourage you to stay updated on the latest   │
# │  trends and developments in AI. Whether you are a tech professional, a business owner, or a researcher,         │
# │  understanding the nuances of AI is key to navigating the ever-evolving technological landscape. To kickstart   │
# │  your journey, consider downloading our free AI trends report by subscribing to our newsletter. Stay informed.  │
# │  Stay ahead.                                                                                                    │
# │                                                                                                                 │
# │  In conclusion, Artificial Intelligence in 2021 is a beacon of innovation, pushing the boundaries of what is    │
# │  possible and redefining the way we live, work, and interact with the world. By embracing the potential of AI   │
# │  technologies and fostering responsible practices, we can unlock a future where intelligence knows no bounds.   │
# │  Let's embark on this transformative journey together. #AIInnovation #FutureTech #StayInformed                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1. Use the content plan to craft a compelling blog post on Artificial Intelligence.                      │
# │  2. Incorporate SEO keywords naturally.                                                                         │
# │  3. Sections/Subtitles are properly named in an engaging manner.                                                │
# │  4. Ensure the post is structured with an engaging introduction, insightful body, and a summarizing             │
# │  conclusion.                                                                                                    │
# │  5. Proofread for grammatical errors and alignment with the brand's voice.                                      │
# │                                                                                                                 │
# │  Agent: Content Writer                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Proofread the given blog post for grammatical errors and alignment with the brand's voice.               │
# │  ID: 579167ad-c876-4a66-80fe-c3324590fe9d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Editor                                                                                                  │
# │                                                                                                                 │
# │  Task: Proofread the given blog post for grammatical errors and alignment with the brand's voice.               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Editor                                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # Embracing Artificial Intelligence in 2021: A Sneak Peek into the Future                                      │
# │                                                                                                                 │
# │  Artificial Intelligence (AI), once a concept confined to the realms of science fiction, has seamlessly         │
# │  integrated into our daily lives. Defined as the simulation of human intelligence processes by machines, AI's   │
# │  prominence in today's world is undeniable, revolutionizing sectors, fostering innovation, and unlocking new    │
# │  realms of possibilities.                                                                                       │
# │                                                                                                                 │
# │  ## Latest Trends in Artificial Intelligence                                                                    │
# │                                                                                                                 │
# │  ### Machine Learning and Deep Learning Advancements                                                            │
# │  A standout trend in AI is the ever-evolving landscape of Machine Learning and Deep Learning algorithms. These  │
# │  technologies empower machines to learn from data, identify patterns, and make autonomous decisions.            │
# │  Applications ranging from image recognition to speech synthesis showcase the boundless potential of these      │
# │  advancements.                                                                                                  │
# │                                                                                                                 │
# │  ### Natural Language Processing (NLP) Innovations                                                              │
# │  Another breakthrough in 2021 is in Natural Language Processing, a branch of AI that enables computers to       │
# │  understand, interpret, and generate human language. Progress in NLP has led to advancements in virtual         │
# │  assistants, sentiment analysis, and language translation services, reshaping human interactions with           │
# │  technology.                                                                                                    │
# │                                                                                                                 │
# │  ### AI Ethics and Responsible AI Practices                                                                     │
# │  As AI technologies proliferate, the spotlight on ethical considerations and responsible AI practices           │
# │  intensifies. Upholding principles of fairness, transparency, and accountability in AI systems is paramount to  │
# │  instilling trust and mitigating potential risks associated with their deployment.                              │
# │                                                                                                                 │
# │  ## Key Players in the Artificial Intelligence Industry                                                         │
# │                                                                                                                 │
# │  The AI landscape is shaped by key innovators driving technological progress:                                   │
# │                                                                                                                 │
# │  ### Google Brain                                                                                               │
# │  Google Brain, an AI research team at Google, spearheads the development of cutting-edge machine learning       │
# │  algorithms, influencing global AI advancements significantly.                                                  │
# │                                                                                                                 │
# │  ### OpenAI                                                                                                     │
# │  Dedicated to ensuring that artificial general intelligence benefits humanity, OpenAI prioritizes transparency  │
# │  and collaboration in pushing the boundaries of AI capabilities.                                                │
# │                                                                                                                 │
# │  ### IBM Watson                                                                                                 │
# │  Renowned for its AI-powered cognitive computing platform, IBM Watson excels in data analysis, natural          │
# │  language processing, and machine learning, enabling businesses to gain insights, automate processes, and       │
# │  foster innovation.                                                                                             │
# │                                                                                                                 │
# │  ### Microsoft Azure AI                                                                                         │
# │  Microsoft Azure AI provides a suite of AI services and tools empowering organizations to build AI solutions,   │
# │  from chatbots to predictive analytics, aiming to democratize AI and drive business transformation.             │
# │                                                                                                                 │
# │  ## Noteworthy News in the Artificial Intelligence Field                                                        │
# │                                                                                                                 │
# │  ### Breakthrough in Autonomous Vehicles Technology                                                             │
# │  AI advancements have catalyzed significant progress in autonomous vehicles technology, revolutionizing         │
# │  transportation through self-driving cars and intelligent transportation systems.                               │
# │                                                                                                                 │
# │  ### AI-Powered Healthcare Diagnostics                                                                          │
# │  In healthcare, AI is reshaping diagnostics and personalized medicine, leveraging algorithms to analyze         │
# │  medical images, genetic data, and patient records, aiding healthcare professionals in precise diagnoses and    │
# │  treatment planning.                                                                                            │
# │                                                                                                                 │
# │  ### Rise of AI in Business Automation                                                                          │
# │  AI is pivotal in automating business operations, optimizing supply chains, and enhancing customer service      │
# │  through chatbots, streamlining business processes and customer interactions.                                   │
# │                                                                                                                 │
# │  ## Call to Action                                                                                              │
# │                                                                                                                 │
# │  As we navigate the AI era, staying abreast of the latest trends and developments is crucial for                │
# │  professionals, business owners, and researchers. Understanding AI nuances is key to navigating the evolving    │
# │  tech landscape. Jumpstart your journey by subscribing to our newsletter and downloading the free AI trends     │
# │  report. Stay informed and stay ahead.                                                                          │
# │                                                                                                                 │
# │  Embracing Artificial Intelligence in 2021 symbolizes innovation without bounds, reshaping our lives, work      │
# │  dynamics, and interactions. By harnessing AI technologies responsibly, we unlock a limitless future of         │
# │  intelligence. Let’s embark on this transformative journey together. #AIInnovation #FutureTech #StayInformed    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Proofread the given blog post for grammatical errors and alignment with the brand's voice.               │
# │  Agent: Editor                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ┌───────────────────────── Tracing Preference Saved ──────────────────────────┐
# │                                                                             │
# │  Info: Tracing has been disabled.                                           │
# │                                                                             │
# │  Your preference has been saved. Future Crew/Flow executions will not       │
# │  collect traces.                                                            │
# │                                                                             │
# │  To enable tracing later, do any one of these:                              │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 9b5b42e2-43ae-43e4-865d-8bfec685e4fc                                                                       │
# │  Final Output: # Embracing Artificial Intelligence in 2021: A Sneak Peek into the Future                        │
# │                                                                                                                 │
# │  Artificial Intelligence (AI), once a concept confined to the realms of science fiction, has seamlessly         │
# │  integrated into our daily lives. Defined as the simulation of human intelligence processes by machines, AI's   │
# │  prominence in today's world is undeniable, revolutionizing sectors, fostering innovation, and unlocking new    │
# │  realms of possibilities.                                                                                       │
# │                                                                                                                 │
# │  ## Latest Trends in Artificial Intelligence                                                                    │
# │                                                                                                                 │
# │  ### Machine Learning and Deep Learning Advancements                                                            │
# │  A standout trend in AI is the ever-evolving landscape of Machine Learning and Deep Learning algorithms. These  │
# │  technologies empower machines to learn from data, identify patterns, and make autonomous decisions.            │
# │  Applications ranging from image recognition to speech synthesis showcase the boundless potential of these      │
# │  advancements.                                                                                                  │
# │                                                                                                                 │
# │  ### Natural Language Processing (NLP) Innovations                                                              │
# │  Another breakthrough in 2021 is in Natural Language Processing, a branch of AI that enables computers to       │
# │  understand, interpret, and generate human language. Progress in NLP has led to advancements in virtual         │
# │  assistants, sentiment analysis, and language translation services, reshaping human interactions with           │
# │  technology.                                                                                                    │
# │                                                                                                                 │
# │  ### AI Ethics and Responsible AI Practices                                                                     │
# │  As AI technologies proliferate, the spotlight on ethical considerations and responsible AI practices           │
# │  intensifies. Upholding principles of fairness, transparency, and accountability in AI systems is paramount to  │
# │  instilling trust and mitigating potential risks associated with their deployment.                              │
# │                                                                                                                 │
# │  ## Key Players in the Artificial Intelligence Industry                                                         │
# │                                                                                                                 │
# │  The AI landscape is shaped by key innovators driving technological progress:                                   │
# │                                                                                                                 │
# │  ### Google Brain                                                                                               │
# │  Google Brain, an AI research team at Google, spearheads the development of cutting-edge machine learning       │
# │  algorithms, influencing global AI advancements significantly.                                                  │
# │                                                                                                                 │
# │  ### OpenAI                                                                                                     │
# │  Dedicated to ensuring that artificial general intelligence benefits humanity, OpenAI prioritizes transparency  │
# │  and collaboration in pushing the boundaries of AI capabilities.                                                │
# │                                                                                                                 │
# │  ### IBM Watson                                                                                                 │
# │  Renowned for its AI-powered cognitive computing platform, IBM Watson excels in data analysis, natural          │
# │  language processing, and machine learning, enabling businesses to gain insights, automate processes, and       │
# │  foster innovation.                                                                                             │
# │                                                                                                                 │
# │  ### Microsoft Azure AI                                                                                         │
# │  Microsoft Azure AI provides a suite of AI services and tools empowering organizations to build AI solutions,   │
# │  from chatbots to predictive analytics, aiming to democratize AI and drive business transformation.             │
# │                                                                                                                 │
# │  ## Noteworthy News in the Artificial Intelligence Field                                                        │
# │                                                                                                                 │
# │  ### Breakthrough in Autonomous Vehicles Technology                                                             │
# │  AI advancements have catalyzed significant progress in autonomous vehicles technology, revolutionizing         │
# │  transportation through self-driving cars and intelligent transportation systems.                               │
# │                                                                                                                 │
# │  ### AI-Powered Healthcare Diagnostics                                                                          │
# │  In healthcare, AI is reshaping diagnostics and personalized medicine, leveraging algorithms to analyze         │
# │  medical images, genetic data, and patient records, aiding healthcare professionals in precise diagnoses and    │
# │  treatment planning.                                                                                            │
# │                                                                                                                 │
# │  ### Rise of AI in Business Automation                                                                          │
# │  AI is pivotal in automating business operations, optimizing supply chains, and enhancing customer service      │
# │  through chatbots, streamlining business processes and customer interactions.                                   │
# │                                                                                                                 │
# │  ## Call to Action                                                                                              │
# │                                                                                                                 │
# │  As we navigate the AI era, staying abreast of the latest trends and developments is crucial for                │
# │  professionals, business owners, and researchers. Understanding AI nuances is key to navigating the evolving    │
# │  tech landscape. Jumpstart your journey by subscribing to our newsletter and downloading the free AI trends     │
# │  report. Stay informed and stay ahead.                                                                          │
# │                                                                                                                 │
# │  Embracing Artificial Intelligence in 2021 symbolizes innovation without bounds, reshaping our lives, work      │
# │  dynamics, and interactions. By harnessing AI technologies responsibly, we unlock a limitless future of         │
# │  intelligence. Let’s embark on this transformative journey together. #AIInnovation #FutureTech #StayInformed    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from IPython.display import Markdown
Markdown(result.raw)
# Out:
# # Embracing Artificial Intelligence in 2021: A Sneak Peek into the Future
#
# Artificial Intelligence (AI), once a concept confined to the realms of science fiction, has seamlessly integrated into our daily lives. Defined as the simulation of human intelligence processes by machines, AI's prominence in today's world is undeniable, revolutionizing sectors, fostering innovation, and unlocking new realms of possibilities.
#
# ## Latest Trends in Artificial Intelligence
#
# ### Machine Learning and Deep Learning Advancements
# A standout trend in AI is the ever-evolving landscape of Machine Learning and Deep Learning algorithms. These technologies empower machines to learn from data, identify patterns, and make autonomous decisions. Applications ranging from image recognition to speech synthesis showcase the boundless potential of these advancements.
#
# ### Natural Language Processing (NLP) Innovations
# Another breakthrough in 2021 is in Natural Language Processing, a branch of AI that enables computers to understand, interpret, and generate human language. Progress in NLP has led to advancements in virtual assistants, sentiment analysis, and language translation services, reshaping human interactions with technology.
#
# ### AI Ethics and Responsible AI Practices
# As AI technologies proliferate, the spotlight on ethical considerations and responsible AI practices intensifies. Upholding principles of fairness, transparency, and accountability in AI systems is paramount to instilling trust and mitigating potential risks associated with their deployment.
#
# ## Key Players in the Artificial Intelligence Industry
#
# The AI landscape is shaped by key innovators driving technological progress:
#
# ### Google Brain
# Google Brain, an AI research team at Google, spearheads the development of cutting-edge machine learning algorithms, influencing global AI advancements significantly.
#
# ### OpenAI
# Dedicated to ensuring that artificial general intelligence benefits humanity, OpenAI prioritizes transparency and collaboration in pushing the boundaries of AI capabilities.
#
# ### IBM Watson
# Renowned for its AI-powered cognitive computing platform, IBM Watson excels in data analysis, natural language processing, and machine learning, enabling businesses to gain insights, automate processes, and foster innovation.
#
# ### Microsoft Azure AI
# Microsoft Azure AI provides a suite of AI services and tools empowering organizations to build AI solutions, from chatbots to predictive analytics, aiming to democratize AI and drive business transformation.
#
# ## Noteworthy News in the Artificial Intelligence Field
#
# ### Breakthrough in Autonomous Vehicles Technology
# AI advancements have catalyzed significant progress in autonomous vehicles technology, revolutionizing transportation through self-driving cars and intelligent transportation systems.
#
# ### AI-Powered Healthcare Diagnostics
# In healthcare, AI is reshaping diagnostics and personalized medicine, leveraging algorithms to analyze medical images, genetic data, and patient records, aiding healthcare professionals in precise diagnoses and treatment planning.
#
# ### Rise of AI in Business Automation
# AI is pivotal in automating business operations, optimizing supply chains, and enhancing customer service through chatbots, streamlining business processes and customer interactions.
#
# ## Call to Action
#
# As we navigate the AI era, staying abreast of the latest trends and developments is crucial for professionals, business owners, and researchers. Understanding AI nuances is key to navigating the evolving tech landscape. Jumpstart your journey by subscribing to our newsletter and downloading the free AI trends report. Stay informed and stay ahead.
#
# Embracing Artificial Intelligence in 2021 symbolizes innovation without bounds, reshaping our lives, work dynamics, and interactions. By harnessing AI technologies responsibly, we unlock a limitless future of intelligence. Let’s embark on this transformative journey together. #AIInnovation #FutureTech #StayInformed
